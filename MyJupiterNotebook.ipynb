# %% [markdown]
# ##  **My Jupiter notebook in Jupyter** *due to issues with the access to Watson Studio*

# %% [markdown]
# **Name: Diego UR**
#
# Risk Analyst

# %% [markdown]
# *I am interested in Data science because I think a rigorous process can decrease the inequalities and information asymmetries.*
# <br> *I am also interested because I want to leverage my career by using quantitative methods in a production scale*

# %% [markdown]
# This code is gonna produce a Christmas Tree***

# %%
row = 7
def triangleShape(n):
    for i in range(n): #number of iterations
        for j in range(n-i): 
            print(' ', end=' ')  # what to do in every iteration: 1. print empty space
        for k in range(2*i+1):
            print('*',end=' ')   # 2. print * 2x plus 1 space ahead the iteration number
        print()
        
triangleShape(row)
triangleShape(row)
# Out:
#               *
#             * * *
#           * * * * *
#         * * * * * * *
#       * * * * * * * * *
#     * * * * * * * * * * *
#   * * * * * * * * * * * * *
#               *
#             * * *
#           * * * * *
#         * * * * * * *
#       * * * * * * * * *
#     * * * * * * * * * * *
#   * * * * * * * * * * * * *

# %% [markdown]
# 1. Bulled Item
# 2. Second Bulled Item
# * <a href="https://cognitiveclass.ai/"> Cognitive Class</a>
# * <a href="https://cognitiveclass.ai/"> Cognitive Class</a>
